# %%
#https://www.youtube.com/watch?v=1CjQgk3anw4&t=187s

import requests
from bs4 import BeautifulSoup
import pandas as pd

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
url = ('https://br.tradingview.com/markets/stocks-brazilia/market-movers-active/')
r = requests.get(url, headers=headers)
soup = BeautifulSoup(r.text, 'lxml')

table = soup.find_all('table')[0]

tabela = pd.read_html(str(table),decimal='.')[0]
tabela.rename(columns={'Unnamed: 0': 'TICKER',
                   'Unnamed: 1': 'PREÇO',
                   'Unnamed: 2': 'VAR %',
                   'Unnamed: 3': 'VAR',
                   'Unnamed: 4': 'CLASSIFICAÇÃO',
                   'Unnamed: 5': 'VOLUME',
                   'Unnamed: 6': 'CAP MERCADO',
                   'Unnamed: 7': 'P/L',
                   'Unnamed: 8': 'EPS (12M)',
                   'Unnamed: 9': 'FUNCIONÁRIOS',
                   'Unnamed: 10': 'SETOR'
                  }, inplace = True)

#tabela
tabela.head(50)
# Out:
#                          TICKER   PREÇO    VAR %   VAR CLASSIFICAÇÃO   VOLUME  \
# 0               OIBR3  OI ON N1    1.01   -6.48% -0.07   Venda Forte  46.633M
# 1       C COGN3  COGNA ON ON NM    3.22   -3.01% -0.10   Venda Forte  11.462M
# 2          V VIVR3  VIVER ON NM    2.76   -9.80% -0.30         Venda   9.563M
# 3         CIEL3  CIELO ON EJ NM    3.11   -1.58% -0.05   Venda Forte   6.928M
# 4          EMBR3  EMBRAER ON NM   19.86   -4.47% -0.93        Compra   6.813M
# 5             VALE3  VALE ON NM  106.58   -1.59% -1.72         Venda   6.532M
# 6               B3SA3  B3 ON NM   14.37   -1.84% -0.27         Venda   6.047M
# 7           BBAS3  BRASIL ON NM   29.50    0.00%  0.00         Venda   5.700M
# 8      IRBR3  IRBBRASIL REON NM    5.55   -1.25% -0.07   Venda Forte   5.616M
# 9         C CASH3  MELIUZ ON NM   49.90  -10.89% -6.10         Venda   5.317M
# 10  MGLU3  MAGAZINE LUIZA ON NM   19.87   -1.97% -0.40   Venda Forte   5.235M
# 11        CSNA3  SID NACIONALON   41.26   -3.17% -1.35         Venda   4.707M
# 12      U UGPA3  ULTRAPAR ON NM   15.55   -0.26% -0.04         Venda   4.463M
# 13      CVCB3  CVC BRASIL ON NM   17.36   -7.71% -1.45   Venda Forte   4.104M
# 14     BRDT3  PETROBRAS BRON NM   26.48   -2.83% -0.77         Venda   3.970M
# 15   B BRML3  BR MALLS PARON NM    9.53   -0.73% -0.07   Venda Forte   3.874M
# 16        PRIO3  PETRORIO ON NM   16.94   -2.76% -0.48         Venda   3.844M
# 17          ABEV3  AMBEV S/A ON   16.42   -1.38% -0.23         Venda   3.063M
# 18         BEEF3  MINERVA ON NM    8.26   -3.95% -0.34   Venda Forte   2.827M
# 19     POSI3  POSITIVO TECON NM   11.38   -4.77% -0.57         Venda   2.792M
# 20          AALR3  ALLIAR ON NM   11.25   19.17%  1.81  Compra Forte   2.744M
# 21     AMAR3  LOJAS MARISAON NM    7.00   -4.63% -0.34         Venda   2.726M
# 22       PETR3  PETROBRAS ON N2   29.21   -2.37% -0.71        Compra   2.723M
# 23         HAPV3  HAPVIDA ON NM   15.32   -0.20% -0.03        Compra   2.643M
# 24   C CMIN3  CSNMINERACAOON N2    7.68   -4.48% -0.36   Venda Forte   2.610M
# 25             JBSS3  JBS ON NM   30.74   -1.88% -0.59         Venda   2.599M
# 26         A AERI3  AERIS ON NM    7.08   -8.41% -0.65   Venda Forte   2.048M
# 27       L LWSA3  LOCAWEB ON NM   23.87   -3.94% -0.98         Venda   2.040M
# 28         MRFG3  MARFRIG ON NM   18.86   -3.03% -0.59         Venda   2.032M
# 29    A AMER3  AMERICANAS ON NM   41.71   -3.31% -1.43   Venda Forte   2.022M
# 30          GFSA3  GAFISA ON NM    3.06   -3.77% -0.12   Venda Forte   1.950M
# 31      PTBL3  PORTOBELLO ON NM   12.53   -6.14% -0.82         Venda   1.891M
# 32     SUZB3  SUZANO S.A. ON NM   57.62    1.43%  0.81        Compra   1.890M
# 33      STBP3  SANTOS BRP ON NM    7.97   -5.12% -0.43         Venda   1.849M
# 34     CYRE3  CYRELA REALTON NM   18.69   -1.84% -0.35   Venda Forte   1.788M
# 35        RENT3  LOCALIZA ON NM   56.63   -1.43% -0.82         Venda   1.765M
# 36   V VIVA3  VIVARA S.A. ON NM   30.35    1.64%  0.49         Venda   1.672M
# 37          BRFS3  BRF SA ON NM   23.00   -3.24% -0.77   Venda Forte   1.647M
# 38         MEAL3  IMC S/A ON NM    3.54   -3.01% -0.11   Venda Forte   1.581M
# 39           CSAN3  COSAN ON NM   22.96   -2.67% -0.63         Venda   1.524M
# 40              DMMO3  DOMMO ON    0.85   -3.41% -0.03   Venda Forte   1.501M
# 41         ETER3  ETERNIT ON NM   19.19   -7.87% -1.64         Venda   1.478M
# 42       N NGRD3  NEOGRID ON NM    5.72   -8.48% -0.53   Venda Forte   1.456M
# 43  BBSE3  BBSEGURIDADEON ED NM   20.33   -1.41% -0.29         Venda   1.448M
# 44     H HBSA3  HIDROVIAS ON NM    4.23   -5.79% -0.26   Venda Forte   1.434M
# 45   F FHER3  FER HERINGERON NM   14.84   -3.95% -0.61         Venda   1.429M
# 46      V VAMO3  VAMOS ON EB NM   14.85   -3.74% -0.58         Venda   1.425M
# 47     LREN3  LOJAS RENNERON NM   39.69   -2.82% -1.15   Venda Forte   1.408M
# 48          MOVI3  MOVIDA ON NM   18.50   -3.55% -0.68   Venda Forte   1.313M
# 49          CCRO3  CCR SA ON NM   11.80   -0.59% -0.07         Venda   1.268M
#
#    CAP MERCADO      P/L EPS (12M) FUNCIONÁRIOS                        SETOR
# 0       6.542B        —         —     47179.00                 Comunicações
# 1       6.205B        —     -3.13       600.00          Serviços Comerciais
# 2     429.715M        —     -1.82        82.00         Consumíveis Duráveis
# 3       8.537B    10.78      0.30      4106.00          Serviços Comerciais
# 4      15.273B        —     -3.84     15658.00        Tecnologia Eletrônica
# 5     545.584B     6.13     17.81     74316.00     Minerais não Energéticos
# 6      88.906B    19.47      0.72            —                   Financeiro
# 7      84.175B        —         —     91673.00                   Financeiro
# 8       7.055B        —     -1.36       445.00                   Financeiro
# 9       7.500B        —         —       155.00          Serviços Comerciais
# 10    134.363B   221.44      0.10            —           Comercio de Varejo
# 11     58.807B     4.01     10.88     35053.00     Minerais não Energéticos
# 12     16.999B    20.99      0.73     15946.00         Minerais Energéticos
# 13      4.255B        —     -0.84            —          Consumo de Serviços
# 14     31.746B     7.20      3.74      3370.00        Serviços de Logistica
# 15      8.100B        —     -0.42       495.00                   Financeiro
# 16     14.620B    13.47      1.32            —         Minerais Energéticos
# 17    262.024B    18.05      0.93     50000.00      Consumo de Não Duráveis
# 18      4.529B     8.49      1.04            —      Consumo de Não Duráveis
# 19      1.680B     7.05      1.78      1371.00        Tecnologia Eletrônica
# 20      1.117B        —     -0.56            —            Serviços de Saúde
# 21      1.919B        —     -1.65            —           Comercio de Varejo
# 22    387.089B     3.75      7.85     49050.00         Minerais Energéticos
# 23     59.736B    93.46      0.16            —            Serviços de Saúde
# 24     44.954B     6.00      1.37      9880.00     Minerais não Energéticos
# 25     78.091B     6.50      4.78    250000.00      Consumo de Não Duráveis
# 26      5.923B    48.98      0.17            —           Produção Artesanal
# 27     14.650B  1086.15      0.02            —       Serviços de Tecnologia
# 28     12.920B     3.47      5.60     32010.00      Consumo de Não Duráveis
# 29     38.958B        —     -0.49     11521.00           Comercio de Varejo
# 30    983.293M        —     -0.43       277.00         Consumíveis Duráveis
# 31      1.970B    13.75      0.96            —           Produção Artesanal
# 32     76.649B     6.25      8.92     35000.00  Industrias de Processamento
# 33      7.241B    75.99      0.12      2824.00                  Transportes
# 34      7.321B     3.86      5.01            —                   Financeiro
# 35     43.213B    26.40      2.21     11251.00                   Financeiro
# 36      7.053B    54.04      0.56            —         Consumíveis Duráveis
# 37     19.199B    13.33      1.80            —      Consumo de Não Duráveis
# 38      1.042B        —     -2.31            —          Consumo de Serviços
# 39     43.932B    28.15      0.86     30717.00            Serviços Públicos
# 40    272.882M     5.13      0.17            —         Minerais Energéticos
# 41      1.287B     4.46      4.82      1393.00     Minerais não Energéticos
# 42      1.480B    86.30      0.07            —       Serviços de Tecnologia
# 43     41.172B    11.15      1.87       193.00                   Financeiro
# 44      3.414B        —     -0.21            —                  Transportes
# 45    832.095M     4.74      3.53      1153.00  Industrias de Processamento
# 46     13.937B    51.88      1.26       948.00                   Financeiro
# 47     36.578B    34.03      1.19     24757.00           Comercio de Varejo
# 48      6.930B    11.79      1.69      3328.00                   Financeiro
# 49     23.977B    40.73      0.29     15927.00                  Transportes

# %%
tabela.to_csv('Valores.csv')
