# %%
#https://www.youtube.com/watch?v=BBomKv3NFNc
#import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from datetime import date
 
#!pip install yfinance --upgrade --no-cache-dir
import yfinance as yf
yf.pdr_override()
 
    
#tickers = ['HGRU11.SA','IRDM11.SA','XPML11.SA','HGRE11.SA','VISC11.SA','GGRC11.SA','HCTR11.SA','ALZR11.SA','FEXC11.SA']
#tickers = input(f'Qual o FII:')+'11.SA'

tickers = input(f'Qual a AÇÃO:')+'.SA'
carteira = web.get_data_yahoo(tickers, period='1y')
carteira['Adj Close'].plot(figsize=(22,8), label=tickers.upper())
carteira['Adj Close'].rolling(100).mean().plot(label='Média 100 dias')
plt.legend()
print(date.today())
# Out:
# Qual a AÇÃO:cxse3
# [*********************100%***********************]  1 of 1 completed
# 2021-05-19
