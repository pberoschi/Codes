# %%
# # import requests
# # from bs4 import BeautifulSoup
 
# headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
 
# acao = input(f'Qual é o ticker? ')+'.SA'
# url = (f'https://finance.yahoo.com/quote/{acao}?p={acao}.SA&.tsrc=fin-srch')
 
# r = requests.get(url, headers=headers)
# soup = BeautifulSoup(r.content, 'html.parser')
 
# title = soup.find('div', id='quote-header-info').find('h1').text
# valorAgora = soup.find('div', id='quote-header-info').find('span', {'class':'Trsdu(0.3s)'}).text
# indice = soup.find_all('span',{'class':'Trsdu(0.3s)'})[10].text
# open = soup.find_all('span',{'class':'Trsdu(0.3s)'})[12].text
# variacaoDia = soup.find_all('td',{'class':'Ta(end)'})[4].text
# variacao52semanas = soup.find_all('td',{'class':'Ta(end)'})[5].text
# number = float(indice[0:5])
 
# print(f'*** {title} ***')
# print('-'*40)
# if number > 0:
#   print('>>> ALTA <<<')
# else:
#   print('>>> BAIXA <<<')
# print('-'*40)
# print(f'- Valor agora: R$ {valorAgora} / {indice}')
# print(f'- Abertura: R$ {open}')
# print(f'- Variação (Dia): R$ {variacaoDia}')
# print(f'- Variação (52 semanas): R$ {variacao52semanas}')
# Out:
# Qual é o ticker? MOVI3
# *** Movida Participações S.A. (MOVI3.SA) ***
# ----------------------------------------
# >>> BAIXA <<<
# ----------------------------------------
# - Valor agora: R$ 17.70 / -0.08 (-0.45%)
# - Abertura: R$ 0.00
# - Variação (Dia): R$ 0.00 - 0.00
# - Variação (52 semanas): R$

# %%
# import requests
# from bs4 import BeautifulSoup
 
# headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
 
# acao = ['vale3.Sa','petr4.SA','BBSE3.SA', 'NEOE3.SA','CMIN3.SA']
# fii = ['ABCP11.SA','AFCR11.SA','AFOF11.SA','AIEC11.SA','ALMI11.SA','ALZR11.SA','ARCT11.SA','ARRI11.SA','ATSA11.SA']
# url = (f'https://finance.yahoo.com/quote/{acao}?p={acao}.SA&.tsrc=fin-srch')
 
# r = requests.get(url, headers=headers)
# soup = BeautifulSoup(r.content, 'html.parser')
 
# lista = []
# #for x in fii:
# for x in acao:
#   r = requests.get(f'https://finance.yahoo.com/quote/{x}?p={x}.SA&.tsrc=fin-srch',headers=headers)
#   soup = BeautifulSoup(r.content, 'html.parser')
  
#   title = soup.find('div', id='quote-header-info').find('h1').text
#   valorAgora = soup.find('div', id='quote-header-info').find('span', {'class':'Trsdu(0.3s)'}).text
#   indice = soup.find_all('span',{'class':'Trsdu(0.3s)'})[10].text
#   open = soup.find_all('span',{'class':'Trsdu(0.3s)'})[12].text
#   variacaoDia = soup.find_all('td',{'class':'Ta(end)'})[4].text
#   variacao52semanas = soup.find_all('td',{'class':'Ta(end)'})[5].text
#   number = float(indice[0:5])
  
#   print(f'*** {title} ***')
#   print('-'*40)
#   if number > 0:
#     print('>>> ALTA <<<')
#   else:
#     print('>>> BAIXA <<<')
#   print('-'*40)
#   print(f'- Valor agora: R$ {valorAgora} / {indice}')
#   print(f'- Abertura: R$ {open}')
#   print(f'- Variação (Dia): R$ {variacaoDia}')
#   print(f'- Variação (52 semanas): R$ {variacao52semanas}')
#   print('')
#   print('#'*70)
# Out:
# *** Vale S.A. (VALE3.SA) ***
# ----------------------------------------
# >>> BAIXA <<<
# ----------------------------------------
# - Valor agora: R$ 109.40 / -1.71 (-1.54%)
# - Abertura: R$ 0.00
# - Variação (Dia): R$ 0.00 - 0.00
# - Variação (52 semanas): R$
#
# ######################################################################
# *** Petróleo Brasileiro S.A. - Petrobras (PETR4.SA) ***
# ----------------------------------------
# >>> ALTA <<<
# ----------------------------------------
# - Valor agora: R$ 25.95 / +0.02 (+0.08%)
# - Abertura: R$ 0.00
# - Variação (Dia): R$ 0.00 - 0.00
# - Variação (52 semanas): R$
#
# ######################################################################
# *** BB Seguridade Participações S.A. (BBSE3.SA) ***
# ----------------------------------------
# >>> ALTA <<<
# ----------------------------------------
# - Valor agora: R$ 23.64 / +0.01 (+0.04%)
# - Abertura: R$ 0.00
# - Variação (Dia): R$ 0.00 - 0.00
# - Variação (52 semanas): R$
#
# ...

# %%
# # import requests
# # from bs4 import BeautifulSoup
# # import pandas as pd
 
# headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
 
# acao = ['vale3.Sa','petr4.SA','BBSE3.SA', 'NEOE3.SA','CMIN3.SA']
# fii = ['ABCP11.SA','AFCR11.SA','AFOF11.SA','AIEC11.SA','ALMI11.SA','ALZR11.SA','ARCT11.SA','ARRI11.SA','ATSA11.SA']

# lista = []
# for x in acao:
#   r = requests.get(f'https://finance.yahoo.com/quote/{x}?p={x}.SA&.tsrc=fin-srch',headers=headers)
#   soup = BeautifulSoup(r.content, 'html.parser')
  
#   title = soup.find('div', id='quote-header-info').find('h1').text
#   valorAgora = soup.find('div', id='quote-header-info').find('span', {'class':'Trsdu(0.3s)'}).text
#   indice = soup.find_all('span',{'class':'Trsdu(0.3s)'})[10].text
#   open = soup.find_all('span',{'class':'Trsdu(0.3s)'})[12].text
#   variacaoDia = soup.find_all('td',{'class':'Ta(end)'})[4].text
#   variacao52semanas = soup.find_all('td',{'class':'Ta(end)'})[5].text
#   #number = float(indice[0:5])

  
#   resumo = {
#       'TÍTULO': title,
#       'VALOR AGORA': valorAgora,
#       'INDICE': indice,
#       'ABERTURA': open,
#       'VARIAÇÃO DIA': variacaoDia,
#       'VARIAÇÃO 52 SEM': variacao52semanas
#       }
#   lista.append(resumo)

# df = pd.DataFrame(lista) 
# df
# Out:
#                                             TÍTULO VALOR AGORA  \
# 0                             Vale S.A. (VALE3.SA)      112.14
# 1  Petróleo Brasileiro S.A. - Petrobras (PETR4.SA)       26.25
# 2      BB Seguridade Participações S.A. (BBSE3.SA)       23.50
# 3                       Neoenergia S.A. (NEOE3.SA)       17.67
# 4                    CSN Mineração S.A. (CMIN3.SA)        9.57
#
#            INDICE ABERTURA     VARIAÇÃO DIA VARIAÇÃO 52 SEM
# 0  -2.46 (-2.15%)   112.10  109.84 - 112.78  48.78 - 120.45
# 1  -0.10 (-0.38%)    25.85    25.80 - 26.35   17.74 - 31.76
# 2  +0.23 (+0.99%)    23.23    23.15 - 23.55   21.96 - 30.76
# 3  +0.66 (+3.88%)    16.94    16.86 - 17.74   15.05 - 22.69
# 4  -0.20 (-2.05%)     9.60      9.32 - 9.60    8.09 - 11.20
