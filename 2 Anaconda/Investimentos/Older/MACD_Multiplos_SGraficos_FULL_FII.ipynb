# %%
from selenium import webdriver
from time import sleep
import pandas as pd
# !pip install yfinance --upgrade --no-cache-dir
# !pip install python-telegram-bot
import time
import telegram
import yfinance as yf
import pandas as pd
yf.pdr_override()

pd.options.mode.chained_assignment = None

ticker = [
    "ABCP11.SA",
    "AFCR11.SA",
    "AFOF11.SA",
    "AIEC11.SA",
    "ALMI11.SA",
    "ALZR11.SA",
    "ANCR11B.SA",
    "AQLL11.SA",
    "ARCT11.SA",
    "ARFI11.SA",
    "ARRI11.SA",
    "ATCR11.SA",
    "ATSA11.SA",
    "ATWN11.SA",
    "BARI11.SA",
    "BBFI11.SA",
    "BBFO11.SA",
    "BBIM11.SA",
    "BBPO11.SA",
    "BBRC11.SA",
    "BCFF11.SA",
    "BCIA11.SA",
    "BCRI11.SA",
    "BICE11.SA",
    "BICR11.SA",
    "BLCP11.SA",
    "BLMC11.SA",
    "BLMG11.SA",
    "BLMO11.SA",
    "BLMR11.SA",
    "BMII11.SA",
    "BMLC11.SA",
    "BNFS11.SA",
    "BPFF11.SA",
    "BPML11.SA",
    "BPRP11.SA",
    "BRCO11.SA",
    "BRCR11.SA",
    "BREV11.SA",
    "BRHT11.SA",
    "BRIM11.SA",
    "BRIP11.SA",
    "BRLA11.SA",
    "BROL11.SA",
    "BTAL11.SA",
    "BTCR11.SA",
    "BTLG11.SA",
    "BTRA11.SA",
    "BTSG11.SA",
    "BTSI11.SA",
    "BTWR11.SA",
    "BVAR11.SA",
    "BZEL11.SA",
    "BZLI11.SA",
    "CARE11.SA",
    "CBOP11.SA",
    "CCRF11.SA",
    "CEOC11.SA",
    "CFHI11.SA",
    "CJCT11.SA",
    "CJFI11.SA",
    "CNES11.SA",
    "CORM11.SA",
    "CPFF11.SA",
    "CPTS11.SA",
    "CRFF11.SA",
    "CTXT11.SA",
    "CVBI11.SA",
    "CXCE11.SA",
    "CXCO11.SA",
    "CXRI11.SA",
    "CXTL11.SA",
    "CYCR11.SA",
    "DAMT11.SA",
    "DEVA11.SA",
    "DLMT11.SA",
    "DMAC11.SA",
    "DOVL11.SA",
    "DRIT11.SA",
    "DVFF11.SA",
    "EDFO11.SA",
    "EDGA11.SA",
    "EGYR11.SA",
    "ELDO11.SA",
    "ERCR11.SA",
    "ERPA11.SA",
    "ESTQ11.SA",
    "EURO11.SA",
    "EVBI11.SA",
    "FAED11.SA",
    "FAMB11.SA",
    "FATN11.SA",
    "FCFL11.SA",
    "FDHY11.SA",
    "FEXC11.SA",
    "FGPM11.SA",
    "FIGS11.SA",
    "FIIB11.SA",
    "FIIP11.SA",
    "FINF11.SA",
    "FISC11.SA",
    "FISD11.SA",
    "FIVN11.SA",
    "FLCR11.SA",
    "FLMA11.SA",
    "FLRP11.SA",
    "FMOF11.SA",
    "FPAB11.SA",
    "FPNG11.SA",
    "FTCE11.SA",
    "FVPQ11.SA",
    "GALG11.SA",
    "GCFF11.SA",
    "GCRI11.SA",
    "GESE11.SA",
    "GGRC11.SA",
    "GSFI11.SA",
    "GTLG11.SA",
    "GTWR11.SA",
    "HAAA11.SA",
    "HABT11.SA",
    "HBCR11.SA",
    "HBRH11.SA",
    "HBTT11.SA",
    "HCHG11.SA",
    "HCRI11.SA",
    "HCST11.SA",
    "HCTR11.SA",
    "HFOF11.SA",
    "HGBS11.SA",
    "HGCR11.SA",
    "HGFF11.SA",
    "HGIC11.SA",
    "HGLG11.SA",
    "HGPO11.SA",
    "HGRE11.SA",
    "HGRU11.SA",
    "HLOG11.SA",
    "HOSI11.SA",
    "HPDP11.SA",
    "HRDF11.SA",
    "HREC11.SA",
    "HSAF11.SA",
    "HSLG11.SA",
    "HSML11.SA",
    "HSRE11.SA",
    "HTMX11.SA",
    "HUSC11.SA",
    "HUSI11.SA",
    "IBCR11.SA",
    "IBFF11.SA",
    "IFID11.SA",
    "IFIE11.SA",
    "IRDM11.SA",
    "JBFO11.SA",
    "JFLL11.SA",
    "JPPA11.SA",
    "JPPC11.SA",
    "JRDM11.SA",
    "JSRE11.SA",
    "JTPR11.SA",
    "KEVE11.SA",
    "KFOF11.SA",
    "KINP11.SA",
    "KISU11.SA",
    "KNCR11.SA",
    "KNHY11.SA",
    "KNIP11.SA",
    "KNRE11.SA",
    "KNRI11.SA",
    "KNSC11.SA",
    "LASC11.SA",
    "LATR11.SA",
    "LFTT11.SA",
    "LGCP11.SA",
    "LKDV11.SA",
    "LOFT11.SA",
    "LSPA11.SA",
    "LUGG11.SA",
    "LVBI11.SA",
    "MADS11.SA",
    "MALL11.SA",
    "MAXR11.SA",
    "MBRF11.SA",
    "MCCI11.SA",
    "MCHF11.SA",
    "MFAI11.SA",
    "MFII11.SA",
    "MGCR11.SA",
    "MGFF11.SA",
    "MGHT11.SA",
    "MGLC11.SA",
    "MGLG11.SA",
    "MINT11.SA",
    "MOFF11.SA",
    "MORC11.SA",
    "MORE11.SA",
    "MTOF11.SA",
    "MTRS11.SA",
    "MVFI11.SA",
    "MXRF11.SA",
    "NAVT11.SA",
    "NCHB11.SA",
    "NEWL11.SA",
    "NEWU11.SA",
    "NPAR11.SA",
    "NSLU11.SA",
    "NVHO11.SA",
    "NVIF11.SA",
    "ONEF11.SA",
    "ORPD11.SA",
    "OUFF11.SA",
    "OUJP11.SA",
    "OULG11.SA",
    "OURE11.SA",
    "PABY11.SA",
    "PATB11.SA",
    "PATC11.SA",
    "PATL11.SA",
    "PBLV11.SA",
    "PEMA11.SA",
    "PLCR11.SA",
    "PLOG11.SA",
    "PLRI11.SA",
    "PNDL11.SA",
    "PNPR11.SA",
    "PORD11.SA",
    "PQAG11.SA",
    "PQDP11.SA",
    "PRSN11.SA",
    "PRSV11.SA",
    "PRTS11.SA",
    "PRZS11.SA",
    "PVBI11.SA",
    "QAGR11.SA",
    "QAMI11.SA",
    "QIFF11.SA",
    "RBBV11.SA",
    "RBCO11.SA",
    "RBDS11.SA",
    "RBED11.SA",
    "RBFF11.SA",
    "RBGS11.SA",
    "RBHY11.SA",
    "RBIR11.SA",
    "RBIV11.SA",
    "RBLG11.SA",
    "RBRD11.SA",
    "RBRF11.SA",
    "RBRL11.SA",
    "RBRM11.SA",
    "RBRP11.SA",
    "RBRR11.SA",
    "RBRS11.SA",
    "RBRU11.SA",
    "RBRY11.SA",
    "RBTS11.SA",
    "RBVA11.SA",
    "RBVO11.SA",
    "RCFA11.SA",
    "RCFF11.SA",
    "RCRB11.SA",
    "RCRI11.SA",
    "RDPD11.SA",
    "RECH11.SA",
    "RECR11.SA",
    "RECT11.SA",
    "RECX11.SA",
    "REIT11.SA",
    "RELG11.SA",
    "RFOF11.SA",
    "RMAI11.SA",
    "RNDP11.SA",
    "RNGO11.SA",
    "ROOF11.SA",
    "RRCI11.SA",
    "RSPD11.SA",
    "RVBI11.SA",
    "RZAK11.SA",
    "RZTR11.SA",
    "SADI11.SA",
    "SAIC11.SA",
    "SALI11.SA",
    "SARE11.SA",
    "SBCL11.SA",
    "SCPF11.SA",
    "SDIL11.SA",
    "SEQR11.SA",
    "SFND11.SA",
    "SHDP11.SA",
    "SHOP11.SA",
    "SHPH11.SA",
    "SJAU11.SA",
    "SNFF11.SA",
    "SOLR11.SA",
    "SPAF11.SA",
    "SPTW11.SA",
    "SPVJ11.SA",
    "STRX11.SA",
    "TBOF11.SA",
    "TCIN11.SA",
    "TCPF11.SA",
    "TELD11.SA",
    "TEPP11.SA",
    "TGAR11.SA",
    "THRA11.SA",
    "TORD11.SA",
    "TORM11.SA",
    "TOUR11.SA",
    "TRNT11.SA",
    "TRXB11.SA",
    "TRXF11.SA",
    "TSER11.SA",
    "TSNC11.SA",
    "TSNM11.SA",
    "URPR11.SA",
    "VCJR11.SA",
    "VCRR11.SA",
    "VERE11.SA",
    "VGHF11.SA",
    "VGIP11.SA",
    "VGIR11.SA",
    "VIDS11.SA",
    "VIFI11.SA",
    "VILG11.SA",
    "VINO11.SA",
    "VISC11.SA",
    "VIUR11.SA",
    "VJFD11.SA",
    "VLJS11.SA",
    "VLOL11.SA",
    "VOTS11.SA",
    "VPSI11.SA",
    "VRTA11.SA",
    "VSEC11.SA",
    "VSHO11.SA",
    "VSLH11.SA",
    "VTLT11.SA",
    "VTPA11.SA",
    "VTPL11.SA",
    "VTRT11.SA",
    "VTVI11.SA",
    "VTXI11.SA",
    "VVPR11.SA",
    "VXXV11.SA",
    "WPLZ11.SA",
    "WTSP11.SA",
    "XBXO11.SA",
    "XPCI11.SA",
    "XPCM11.SA",
    "XPHT11.SA",
    "XPIN11.SA",
    "XPLG11.SA",
    "XPML11.SA",
    "XPPR11.SA",
    "XPSF11.SA",
    "XTED11.SA"    
]

# ANALISE DE CADA PAPEL
if ticker:
    for x in ticker:
        dia2 = yf.Ticker(x)
        Dia = dia2.history(period='1d', interval='5m').tail(1)
        Ano = yf.download(x, period='1y')
        print(x)     
        #ANO: criando coluna Data e transferindo valores
        Ano.insert(loc=0, column='DataMain', value=Ano.index)
        #remove a ultima data
        removedata = Ano.loc[(Ano['DataMain']==pd.to_datetime('today').normalize())]
        Ano = Ano.drop(removedata.index)
        #DIA: criando coluna Data e transferindo valores
        Dia.insert(loc=0, column='DataMain', value=Dia.index)
        #unindo os periodos
        Resumo = Ano.append(Dia)
        #ajuste da data
        Resumo['DataMain'] = pd.to_datetime(Resumo['DataMain'], utc=True).dt.date
        #resumindo as colunas desejadas (data e fechamento)
        ResumoEnd = Resumo[['DataMain', 'Close']]
        #calculo MACD
        rapidoMME = ResumoEnd.Close.ewm(span=12).mean()
        lentaMME = ResumoEnd.Close.ewm(span=26).mean()
        MACD = rapidoMME - lentaMME
        Sinal = MACD.ewm(span=9).mean()
        ResumoEnd['MACD'] = MACD
        ResumoEnd['Sinal'] = Sinal
        #ajuste index e retira data; coloca data como index
        ResumoEnd = ResumoEnd.set_index(pd.DatetimeIndex(ResumoEnd['DataMain'].values))
        ResumoEnd = ResumoEnd.drop('DataMain', 1)
        # criar código para verificar a compra ou venda
        ResumoEnd['flag'] = ''
        ResumoEnd['preco_compra'] = ''
        ResumoEnd['preco_venda'] = ''
        for i in range (1, len(ResumoEnd.Sinal)):
          if ResumoEnd['MACD'][i] > ResumoEnd['Sinal'][i]:
            if ResumoEnd['flag'][i-1] == 'C':
              ResumoEnd['flag'][i] = 'C'
            else:
              ResumoEnd['flag'][i] = 'C'
              ResumoEnd['preco_compra'][i] = ResumoEnd['Close'][i]

          elif ResumoEnd['MACD'][i] < ResumoEnd['Sinal'][i]:
            if ResumoEnd['flag'][i-1] == 'V':
                ResumoEnd['flag'][i] = 'V'
            else:
                ResumoEnd['flag'][i] = 'V'
                ResumoEnd['preco_venda'][i] = ResumoEnd['Close'][i]

        # mensagem ao TELEGRAM
        my_token = '1852343442:AAEBBS1NjjFRIqt-XTbb3rzRxipvk8ZqI5I'
        chat_id = '-351556985'
        def envia_mensagem(msg, chat_id, token = my_token):
          bot = telegram.Bot(token = token)
          bot.sendMessage(chat_id = chat_id, text=msg)
        hoje = ResumoEnd.flag[-1]
        ontem = ResumoEnd.flag[-2]
        flag = hoje
        ticker2 = x[0:-3]
        site = f'https://www.google.com/search?q={ticker2}&rlz=1C1EJFC_enBR915BR916&oq={ticker2}&aqs=chrome..69i57j0l5j0i10i433j69i60.4408j0j7&sourceid=chrome&ie=UTF-8'
        preco_fechamento = round(ResumoEnd.Close.tail(1)[-1],2)
        msg = f'\n *** FII *** \n{ticker2}  \n>>> {flag} <<< \nPreço de Fechamento: {preco_fechamento}\n\nTotal de FUNDOS analisadas: {len(ticker)}'
        #verificar se houve alteração do sinal
        #if ontem != hoje:
          #envia_mensagem(msg, chat_id, my_token)
        #time.sleep(0.5)
    else:
        print(f'{ticker} não encontrado')
# Out:
# Requirement already satisfied: yfinance in /home/johnny/anaconda3/lib/python3.8/site-packages (0.1.59)
# Requirement already satisfied: lxml>=4.5.1 in /home/johnny/anaconda3/lib/python3.8/site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: multitasking>=0.0.7 in /home/johnny/anaconda3/lib/python3.8/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: requests>=2.20 in /home/johnny/anaconda3/lib/python3.8/site-packages (from yfinance) (2.25.1)
# Requirement already satisfied: pandas>=0.24 in /home/johnny/anaconda3/lib/python3.8/site-packages (from yfinance) (1.2.4)
# Requirement already satisfied: numpy>=1.15 in /home/johnny/anaconda3/lib/python3.8/site-packages (from yfinance) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/johnny/anaconda3/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/johnny/anaconda3/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2021.1)
# Requirement already satisfied: six>=1.5 in /home/johnny/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/johnny/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /home/johnny/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/johnny/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/johnny/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (4.0.0)
# Requirement already satisfied: python-telegram-bot in /home/johnny/anaconda3/lib/python3.8/site-packages (13.6)
# Requirement already satisfied: cachetools==4.2.2 in /home/johnny/anaconda3/lib/python3.8/site-packages (from python-telegram-bot) (4.2.2)
# Requirement already satisfied: certifi in /home/johnny/anaconda3/lib/python3.8/site-packages (from python-telegram-bot) (2020.12.5)
# Requirement already satisfied: pytz>=2018.6 in /home/johnny/anaconda3/lib/python3.8/site-packages (from python-telegram-bot) (2021.1)
# Requirement already satisfied: APScheduler==3.6.3 in /home/johnny/anaconda3/lib/python3.8/site-packages (from python-telegram-bot) (3.6.3)
# Requirement already satisfied: tornado>=6.1 in /home/johnny/anaconda3/lib/python3.8/site-packages (from python-telegram-bot) (6.1)
# Requirement already satisfied: setuptools>=0.7 in /home/johnny/anaconda3/lib/python3.8/site-packages (from APScheduler==3.6.3->python-telegram-bot) (52.0.0.post20210125)
# Requirement already satisfied: six>=1.4.0 in /home/johnny/anaconda3/lib/python3.8/site-packages (from APScheduler==3.6.3->python-telegram-bot) (1.15.0)
# Requirement already satisfied: tzlocal>=1.2 in /home/johnny/anaconda3/lib/python3.8/site-packages (from APScheduler==3.6.3->python-telegram-bot) (2.1)
# -
#     "ABCP11.SA",
#     "AFCR11.SA",
#     "AFOF11.SA",
#     "AIEC11.SA",
#     "ALMI11.SA",
#     "ALZR11.SA",
#     ANCR11B.SA: No data found, symbol may be delisted
# [*********************100%***********************]  7 of 7 completed
#
# 6 Failed downloads:
# - "ALMI11.SA": No data found, symbol may be delisted
# - "AIEC11.SA": No data found, symbol may be delisted
# - "ABCP11.SA": No data found, symbol may be delisted
# - "ALZR11.SA": No data found, symbol may be delisted
# - "AFOF11.SA": No data found, symbol may be delisted
# - "AFCR11.SA": No data found, symbol may be delisted
#
#     "ABCP11.SA",
#     "AFCR11.SA",
#     "AFOF11.SA",
#     "AIEC11.SA",
#     "ALMI11.SA",
#     "ALZR11.SA",
#     ANCR11B.SA
# /home/johnny/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/multi.py:3587: RuntimeWarning: The values in the array are unorderable. Pass `sort=False` to suppress this warning.
#   uniq_tuples = lib.fast_unique_multiple([self._values, other._values], sort=sort)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-4e36f7ed4c43> in <module>
#     390         Dia.insert(loc=0, column='DataMain', value=Dia.index)
#     391         #unindo os periodos
# --> 392         Resumo = Ano.append(Dia)
#     393         #ajuste da data
#     394         Resumo['DataMain'] = pd.to_datetime(Resumo['DataMain'], utc=True).dt.date
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7980             to_concat = [self, other]
#    7981         return (
# -> 7982             concat(
#    7983                 to_concat,
#    7984                 ignore_index=ignore_index,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     296     )
#     297
# --> 298     return op.get_result()
#     299
#     300
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     518                 mgrs_indexers.append((obj._mgr, indexers))
#     519
# --> 520             new_data = concatenate_block_managers(
#     521                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     522             )
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/concat.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#      66                 values = values.view()
#      67             b = b.make_block_same_class(values, placement=placement)
# ---> 68         elif _is_uniform_join_units(join_units):
#      69             blk = join_units[0].block
#      70             vals = [ju.block.values for ju in join_units]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/concat.py in _is_uniform_join_units(join_units)
#     489         # no blocks that would get missing values (can lead to type upcasts)
#     490         # unless we're an extension dtype.
# --> 491         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     492         and
#     493         # no blocks with indexers (as then the dimensions do not fit)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/concat.py in <genexpr>(.0)
#     489         # no blocks that would get missing values (can lead to type upcasts)
#     490         # unless we're an extension dtype.
# --> 491         all(not ju.is_na or ju.block.is_extension for ju in join_units)
#     492         and
#     493         # no blocks with indexers (as then the dimensions do not fit)
#
# AttributeError: 'NoneType' object has no attribute 'is_extension'
