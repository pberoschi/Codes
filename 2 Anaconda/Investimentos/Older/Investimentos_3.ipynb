# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# !pip install yfinance --upgrade --no-cache-dir
import yfinance as yf
yf.pdr_override()

ticker = web.get_data_yahoo('petr4.sa', period='1y')

ticker.tail(50)

abertura = ticker['Open']
alta = ticker['High']
baixa = ticker['Low']
ticker['Open'].plot(figsize=(22,8), label='Abertura')
ticker['High'].plot(figsize=(22,8), label='Alta')
ticker['Low'].plot(figsize=(22,8), label='Baixa') 
plt.legend()
print(f'Abertura: {abertura.mean()}')
print(f'Alta: {alta.mean()}')
print(f'Baixa: {baixa.mean()}')


import seaborn as sns

sns.set()
ticker['Open'].plot(figsize=(22,8), label='Abertura')
ticker['High'].plot(figsize=(22,8), label='Alta')
ticker['Low'].plot(figsize=(22,8), label='Baixa') 
plt.legend()
# Out:
# ...
# [*********************100%***********************]  1 of 1 completed
# Abertura: 23.482307712076164
# Alta: 23.862510117442017
# Baixa: 23.106356284879
