# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
from time import sleep
from selenium.webdriver.chrome.options import Options

url = 'https://www.passagensimperdiveis.com.br/categoria/pacotes-nacionais/'

option = Options()
option.headless = True
driver = webdriver.Chrome(options=option)     # NAVEGADOR OFF
#driver = webdriver.Chrome()                  # NAVEGADOR ON
driver.get(url)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

#matriz = soup.find('div',{'class':'container'})
matriz = soup.find_all('div',{'class':'col-12 col-md-6'})

driver.close()

# %%
matriz
# Out:
# [<div class="col-12 col-md-6">
#  <h2 itemprop="headline"><a href="https://www.passagensimperdiveis.com.br/promocao-de-passagens-mais-hotel-4-estrelas-para-brasil-gramado-2022-24/"><strong>PASSAGEM + HOTEL 4 ESTRELAS</strong> em <strong>GRAMADO</strong>! A partir de R$ 881, por pessoa, quarto duplo, c/ taxas! Opções com CAFÉ DA MANHÃ incluso!</a></h2>
#  <p class="entry-promo">PASSAGEM + HOTEL 4 ESTRELAS em GRAMADO! A partir de R$ 881, por pessoa, quarto duplo, c/ taxas! Opções com CAFÉ DA MANHÃ incluso!</p>
#  </div>,
#  <div class="col-12 col-md-6">
#  <div class="media list-promo-page">
#  <figure itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#  <a href="https://www.passagensimperdiveis.com.br/promocao-de-pacote-flexiveis-para-brasil-gramado-2022-6/">
# ...

# %%
for item in matriz:
    #oferta = item.find('a')['href']
    oferta = item.find('h3',{'class':'mt-0 custom-h5-promo'})

    print(f'{oferta}\n')

#driver.close()
print('Fim do Script')
# Out:
# None
#
# <h3 class="mt-0 custom-h5-promo"><a href="https://www.passagensimperdiveis.com.br/promocao-de-pacote-flexiveis-para-brasil-gramado-2022-6/">Pacote Promo/Pacote Flexível! <strong>PASSAGEM + HOTEL</strong> em <strong>GRAMADO</strong>! A partir de R$ 403, por pessoa, quarto duplo, c/ taxas! Em até 12x no cartão!<span class="lente-transparencia"></span></a></h3>
#
# <h3 class="mt-0 custom-h5-promo"><a href="https://www.passagensimperdiveis.com.br/promocao-de-passagens-mais-hotel-4-estrelas-para-brasil-campos-do-jordao-2022-14/"><strong>PASSAGEM + HOTEL 4 ESTRELAS</strong> em <strong>CAMPOS DO JORDÃO</strong>! A partir de R$ 704, por pessoa, quarto duplo, c/ taxas! Opções com CAFÉ DA MANHÃ incluso!<span class="lente-transparencia"></span></a></h3>
#
# ...

# %%
teste = matriz.find('')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-7e259d0cf033> in <module>
# ----> 1 teste = matriz.find('')
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
